# %% [markdown]
# # Cross-Country Comparison

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import kruskal

# %% [markdown]
# ##### Import your EDA class

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)
from src.comparison import CountryComparator

# %%
print("🌍 Starting Cross-Country Solar Analysis Comparison...")
# Out:
# 🌍 Starting Cross-Country Solar Analysis Comparison...

# %% [markdown]
# ##### Initialize comparator

# %%
comparator = CountryComparator()

# %% [markdown]
# ##### Define country files

# %%
countries = {
    'Benin': '../data/benin_clean.csv',
    'Sierra Leone': '../data/sierraleone_clean.csv', 
    'Togo': '../data/togo_clean.csv'
}

# %% [markdown]
# ##### Load and combine data

# %%
print("📊 Loading country data...")
combined_data = comparator.load_and_combine(countries)
# Out:
# 📊 Loading country data...
# ✅ Combined 3 countries with 1576800 total rows

# %% [markdown]
# ##### BOXPLOTS (Required: Boxplots of GHI, DNI, DHI side-by-side)

# %%
comparator.generate_boxplots()

# %% [markdown]
# ##### SUMMARY STATISTICS (Required: Summary Table comparing mean, median, std)

# %%
summary = comparator.calculate_summary_stats()
print(f"📈 {summary}")
# Out:
# 📈                      GHI                            DNI                     \
#                     mean median         std        mean median         std
# country
# Benin         240.559452    1.8  331.131327  167.187516   -0.1  261.710501
# Sierra Leone  201.957515    0.3  298.495150  116.376337   -0.1  218.652659
# Togo          230.555040    2.1  322.532347  151.258469    0.0  250.956962
#
#                      DHI
#                     mean median         std
# country
# Benin         115.358961    1.6  158.691074
# Sierra Leone  113.720571   -0.1  158.946032
# Togo          116.444352    2.5  156.520714

# %%
comparator.statistical_test()
# Out:
# Kruskal-Wallis Results:
# H-statistic: 4524.8835
# p-value: 0.000000
# ✅ Statistically significant differences between countries
# (np.float64(4524.883491942792), np.float64(0.0))

# %%
ranking = comparator.plot_ranking(metric='GHI')
print("Country Ranking (Highest to Lowest GHI):")
for i, (country, ghi) in enumerate(ranking.items(), 1):
    print(f"#{i}: {country} - {ghi:.2f} W/m²")
# Out:
# Country Ranking (Highest to Lowest GHI):
# #1: Benin - 240.56 W/m²
# #2: Togo - 230.56 W/m²
# #3: Sierra Leone - 201.96 W/m²

# %%
comparator.generate_bubble_chart()
# Out:
# c:\Users\ourbarn\Desktop\solar-challenge-week0\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
comparator.generate_histograms()

# %%
comparator.generate_correlation_heatmaps()

# %%
comparator.generate_scatter_plots()
# Out:
# c:\Users\ourbarn\Desktop\solar-challenge-week0\src\comparison.py:180: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# c:\Users\ourbarn\Desktop\solar-challenge-week0\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
comparator.generate_wind_analysis()

# %%
best_ghi_country = ranking.index[0]
best_ghi_value = ranking.iloc[0]

# %% [markdown]
# ##### Get consistency (lowest standard deviation)

# %%
std_by_country = combined_data.groupby('country')['GHI'].std()
most_consistent = std_by_country.idxmin()
least_consistent = std_by_country.idxmax()

# %%
print("\n💡 **SOLAR INVESTMENT INSIGHTS:**")
print(f"• **{best_ghi_country}** has the HIGHEST solar potential ({best_ghi_value:.1f} W/m²) - Best for maximum energy production")
print(f"• **{most_consistent}** offers the MOST CONSISTENT solar output - Best for stable energy supply")
print(f"• **{least_consistent}** has the MOST VARIABLE output - Higher risk but potential for peak production")
# Out:
# 💡 **SOLAR INVESTMENT INSIGHTS:**
# • **Benin** has the HIGHEST solar potential (240.6 W/m²) - Best for maximum energy production
# • **Sierra Leone** offers the MOST CONSISTENT solar output - Best for stable energy supply
# • **Benin** has the MOST VARIABLE output - Higher risk but potential for peak production
