# %% [markdown]
# # Sierraleone Solar Data Analysis

# %%
import os
import sys

# %% [markdown]
# ##### Import your EDA class

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)
from src.eda import SolarDataEDA

# %% [markdown]
# ##### Initialize and run analysis

# %%
print("🔍 Starting Sierraleone Solar Data Analysis...")
sierra_data = SolarDataEDA("../data/sierraleone_clean.csv")
df_sierra = sierra_data.load_data()
df_sierra = sierra_data.clean_data()
# Out:
# 🔍 Starting Sierraleone Solar Data Analysis...
# ✅ Data loaded successfully!
# ✅ Data cleaning completed!

# %% [markdown]
# ##### Run all EDA methods

# %%
sierra_data.basic_info()
# Out:
#                      GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# Timestamp
# 2021-10-30 00:01:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 2021-10-30 00:02:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2021-10-30 00:03:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2021-10-30 00:04:00 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 2021-10-30 00:05:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#                      WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  \
# Timestamp
# 2021-10-30 00:01:00      0.0  0.0      0.0  1002         0            0.0
# 2021-10-30 00:02:00      0.0  0.0      0.0  1002         0            0.0
# 2021-10-30 00:03:00      0.0  0.0      0.0  1002         0            0.0
# 2021-10-30 00:04:00      0.0  0.0      0.0  1002         0            0.1
# 2021-10-30 00:05:00      0.0  0.0      0.0  1002         0            0.0
#
#                      TModA  TModB  Outliers
# Timestamp
# ...

# %%
sierra_data.time_series_analysis()

# %%
sierra_data.daily_solar_patterns()
# Out:
# c:\Users\ourbarn\Desktop\solar-challenge-week0\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sierra_data.correlation_analysis()
# Out:
# c:\Users\ourbarn\Desktop\solar-challenge-week0\src\eda.py:119: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\ourbarn\Desktop\solar-challenge-week0\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sierra_data.distribution_analysis()
# Out:
# c:\Users\ourbarn\Desktop\solar-challenge-week0\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sierra_data.outlier_analysis()
print("✅ Benin analysis complete!")
# Out:
# c:\Users\ourbarn\Desktop\solar-challenge-week0\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 Outlier Summary: 16292 rows with outliers
# ✅ Benin analysis complete!
